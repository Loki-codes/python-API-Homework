# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# !jupyter nbextension enable --py gmaps
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from api_keys import g_key
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#importing info from cities.csv
ctyInfo = pd.read_csv('../output_data/cities.csv') 
#making the info into a Data Frame
df = pd.DataFrame(ctyInfo)
df.head()
# Out:
#   City Name  Temperature  Maximum Temp  Wind  Cloudiness  Latitude  Longitude  \
# 0   Te Anau         9.56          9.56  0.19          39  -45.4167   167.7167
# 1  Novikovo       -10.45        -10.45  3.19           0   51.1537    37.8879
# 2   Rozivka        -5.45         -5.45  4.34           0   46.9385    35.7724
# 3     Kapaa        22.57         23.33  4.12          75   22.0752  -159.3190
# 4    Maceió        27.00         27.00  3.60           0   -9.6658   -35.7353
#
#    Humidity
# 0        83
# 1        71
# 2        40
# 3        88
# 4        78

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#I made a heat map
locations = df[['Latitude', 'Longitude']]
fig = gmaps.figure()
layer = gmaps.heatmap_layer(locations, weights=df['Humidity'], dissipating=False, max_intensity= 100, point_radius= 3)
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#I like a little bit of couds so I made the coul
ndf = df.loc[((df['Humidity']< 80) & (df['Humidity'] > 70) & (df['Wind']< 10) & (df['Cloudiness']< 10)& (df['Temperature'] > 10))]
ndf.head()
# Out:
#              City Name  Temperature  Maximum Temp  Wind  Cloudiness  Latitude  \
# 4               Maceió        27.00         27.00  3.60           0   -9.6658
# 42          Kaitangata        10.53         10.53  2.51           1  -46.2817
# 109  São João da Barra        27.00         27.00  5.14           0  -21.6403
# 159        Bandarbeyla        24.97         24.97  3.57           0    9.4942
# 237            Fortuna        11.91         13.33  5.66           1   40.5982
#
#      Longitude  Humidity
# 4     -35.7353        78
# 42    169.8464        77
# 109   -41.0511        78
# 159    50.8122        74
# 237  -124.1573        71

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ndf
hotel_df.reset_index()
hotel_df["Hotel Name"] = ""


    
for index, row in hotel_df.iterrows():
    try:
        target_city = row['City Name']
        lat = row['Latitude']
        lng = row['Longitude']
        target_url = (f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&keyword=Lodging&radius=5000&type=Lodging&key={g_key}')
        #print(target_url)
        request = requests.get(target_url).json()
        hotel_df.loc[index, "Hotel Name"] = request['results'][0]['name']
    except:
        print()
# Out:
# <ipython-input-74-d793fca55800>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""

# %%
pprint(request['results'])
hotel_df.head()
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6821956, 'lng': 92.7238641},
#                'viewport': {'northeast': {'lat': 11.68356012989272,
#                                           'lng': 92.72526322989272},
#                             'southwest': {'lat': 11.68086047010728,
#                                           'lng': 92.72256357010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Salt life',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 945,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/100300813144160516257">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwK_mHuRMrqnOn2PYCza0Kp-jel57ZD0oHaO7eUwQ_aQzQLPfwjx7xKU3-j2-D_4YnDHeChog59zCzmGnGXRUPw00AWM3wtFvZbDWEw9P_CLYmAHRxg8-bdbVVK5qqf-1u-HbFjiMCYYdPlW0cJKopjbJQ0ddWlZrA4INgPo6riaVjIY',
#               'width': 1680}],
#   'place_id': 'ChIJ2eI-QfCViDARyd2IT0ee6_A',
#   'plus_code': {'compound_code': 'MPJF+VG Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPJF+VG'},
#   'rating': 4.5,
#   'reference': 'ChIJ2eI-QfCViDARyd2IT0ee6_A',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 82,
#   'vicinity': 'Sea shore, road, Haddo, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6497772, 'lng': 92.7296827},
#                'viewport': {'northeast': {'lat': 11.65107232989272,
#                                           'lng': 92.73102667989272},
#                             'southwest': {'lat': 11.64837267010728,
#                                           'lng': 92.72832702010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': "Kanchan's Nest",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 809,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/115270494698403485175">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwJ44zob-3-pV1FG63aNA47rXDZ2SEU7flAL6RT4IFqm8MsZX27je_JSnaBm2sgFj1VzwRZV3IVBeecTAdXbg_nEA0CG_NwbmSm80XbCo-JPJPR57l2xqVxB6GCZqwmLiUGhqIMyvjHVAejfOq1w3db5OWqNCJrBFk1K-fSa4pPrxYDB',
#               'width': 1439}],
#   'place_id': 'ChIJ0S93bAWViDAROQDvFjEPcO4',
#   'plus_code': {'compound_code': 'JPXH+WV Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JJPXH+WV'},
#   'rating': 4.8,
#   'reference': 'ChIJ0S93bAWViDAROQDvFjEPcO4',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 50,
#   'vicinity': 'Lamba Line, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6761772, 'lng': 92.74020039999999},
#                'viewport': {'northeast': {'lat': 11.67734207989272,
#                                           'lng': 92.7416864798927},
#                             'southwest': {'lat': 11.67464242010728,
#                                           'lng': 92.73898682010726}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Welcomhotel Bay Island Port Blair',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1954,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/117868258779402998319">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwLrDis_CH5A6P_AbhFwNZpc1KaF0EQOkF__HHgaDvGIV-jTUgJYItUfCT4OykpnDFUAB4ngXqt9ajhZwl1BbSQxuXNvnTK3xDpEAA2S1jvwMj0mQosQamBr5_ulcdRxzJsJbHfBmnkLQvDNTFBMMBhwnEH_EtaXt7_3bFJuE7Je4xEJ',
#               'width': 2829}],
#   'place_id': 'ChIJh_mDIBWViDARFwf2YL6xKRQ',
#   'plus_code': {'compound_code': 'MPGR+F3 Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPGR+F3'},
#   'rating': 4.2,
#   'reference': 'ChIJh_mDIBWViDARFwf2YL6xKRQ',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 833,
#   'vicinity': 'Marine Hill, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6340611, 'lng': 92.72136979999999},
#                'viewport': {'northeast': {'lat': 11.63548492989272,
#                                           'lng': 92.72272397989273},
#                             'southwest': {'lat': 11.63278527010728,
#                                           'lng': 92.72002432010729}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel Horizon Hues',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 853,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/107091979814013118550">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwLhPK9nNsGDrHIwHPVnuy0nk6tENmN5cD11060m9vjFi2qUet1YJuX3QXqRCXPTEN2OFuC495VNZyYl_rPJWXNt6upq7gfIaSn0Qq9PXgGuezwuSgroFYAs8Xo9tAchDz_Fyy2JxiMvO9CL9ig59MVqIyrBuoM57qYm0KJnje-NqBmt',
#               'width': 1280}],
#   'place_id': 'ChIJ7aRYGMiViDARtJvGmXzLJXM',
#   'plus_code': {'compound_code': 'JPMC+JG Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JJPMC+JG'},
#   'rating': 4.8,
#   'reference': 'ChIJ7aRYGMiViDARtJvGmXzLJXM',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 23,
#   'vicinity': 'Old Pahargaon Polytechnic Road Post, near Canara Bank, '
#               'Dollygunj, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.680665, 'lng': 92.72056090000001},
#                'viewport': {'northeast': {'lat': 11.68203122989272,
#                                           'lng': 92.72191002989273},
#                             'southwest': {'lat': 11.67933157010728,
#                                           'lng': 92.71921037010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel De Pebbles',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1032,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/111095347337969977478">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwJhOhRuv_39yFPne_zOiQOa3gNvkofo4c4i16EfcPuGFBwJzCeWFOG12-sq0AKdpzLowBHDZnziZuq9SYlIlSeGT-2BPCf-CitYdsSujljEDzTcLwdjqDBQsq3Xd-Nuljv7gf3e2ZjtC5YAtd1mBWtXRso0GDAwr3PtG_DhEVz5YSXE',
#               'width': 774}],
#   'place_id': 'ChIJydKX8o2ViDARqC8idSjblDE',
#   'plus_code': {'compound_code': 'MPJC+76 Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPJC+76'},
#   'rating': 4.8,
#   'reference': 'ChIJydKX8o2ViDARqC8idSjblDE',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 212,
#   'vicinity': 'DePebbles Hotel, Jawaharlal Nehru Road, Haddo, Port Blair'},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'geometry': {'location': {'lat': 11.670454, 'lng': 92.7294964},
#                'viewport': {'northeast': {'lat': 11.67180252989272,
#                                           'lng': 92.73083167989272},
#                             'southwest': {'lat': 11.66910287010728,
#                                           'lng': 92.72813202010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'SriRadha Nivas Homestay',
#   'permanently_closed': True,
#   'photos': [{'height': 673,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/104997997822907525669">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwKbLwwGkTy9WxQhPpWFCSrDLKchXGoyqbKz4mc28Tosg2wWuZm7QU39axJFrSjCt-fD385NvRvmpxdsebXXldbY6nkXkV34cNpL6KkROULiX5W71BO8UScWI_1rhHML2PPg-FlgnV8G6gj_-S-7dRWPxhJagvCUL1dHqvcH2cXp2_sV',
#               'width': 1200}],
#   'place_id': 'ChIJj66G3QCViDARYoRVtG8YRHw',
#   'plus_code': {'compound_code': 'MPCH+5Q Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPCH+5Q'},
#   'rating': 4.8,
#   'reference': 'ChIJj66G3QCViDARYoRVtG8YRHw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 92,
#   'vicinity': '30, Anarkali, Delanipur, Haddo, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6319896, 'lng': 92.7136025},
#                'viewport': {'northeast': {'lat': 11.63335032989272,
#                                           'lng': 92.71494442989272},
#                             'southwest': {'lat': 11.63065067010728,
#                                           'lng': 92.71224477010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel Value Luxury Stay Andaman',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/100404301298900286655">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwIPjJjRjV3ZP4FbxPyEEVz6UIvX2Kexl6PDfk9czAUK6dGw5-86BXhch2rH-Quq1RuNRE1vuYuIF6coZSN1blTaowT13BEAUWdElwY9puS2_YVj5Wf-mQHO-YMrOmN23g_ZxQ5Ts1z1kUnld3v_-VMl8HT23Li7qA0ksoiBEV-E-Gv_',
#               'width': 4032}],
#   'place_id': 'ChIJLxrCE7CViDARtKpjzI-sUUE',
#   'plus_code': {'compound_code': 'JPJ7+QC Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JJPJ7+QC'},
#   'rating': 5,
#   'reference': 'ChIJLxrCE7CViDARtKpjzI-sUUE',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 111,
#   'vicinity': 'school, masjid, 03 kms from airport next to garden gate '
#               'apartment, opp. to Dollygunj, near to dollygunj, Dollygunj, '
#               'Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.673653, 'lng': 92.73924199999999},
#                'viewport': {'northeast': {'lat': 11.67503262989272,
#                                           'lng': 92.74061902989273},
#                             'southwest': {'lat': 11.67233297010728,
#                                           'lng': 92.73791937010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel Reef Atlantis',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/109130719975126547873">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwImVo2YozdstLu3a1DQn7EbZ6bIQNQIZ4-bdh-JBDhRnYoXr7_rC_-NGkETPvIZVF1GtjvaIm94xAlpvF3u6VksodGMg4ygU1bFkdVwgiIVnV0quTZ7NWRYwkBonE_JrHfLQVuGypw6llQxuulxQSO963BS4Ts9bkma18jxr_16SAxN',
#               'width': 2252}],
#   'place_id': 'ChIJkzxfrbeViDARkpusMPw3_Rs',
#   'plus_code': {'compound_code': 'MPFQ+FM Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPFQ+FM'},
#   'rating': 4.9,
#   'reference': 'ChIJkzxfrbeViDARkpusMPw3_Rs',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 73,
#   'vicinity': 'Near, Sisty Nagar, Marine Gate, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.669106, 'lng': 92.7333307},
#                'viewport': {'northeast': {'lat': 11.67031252989272,
#                                           'lng': 92.73462547989271},
#                             'southwest': {'lat': 11.66761287010728,
#                                           'lng': 92.73192582010726}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'The Harriet View BnB',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2069,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/112696809199511193720">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwKR2t8w9FgWHY8P1lskCM1PKTXS6_6OI-Ir16rUb3N8LMdUw6inX_m0w0ybkMoJPR4aKCQIMOZ2S0U9dswXLdHkzMaeIPznZx2HH8C036uqNTSmkpLQFr1RKS9HKhGFljJ1cTMRsdOlKpo3gcBFXWmYxUmiSUANkOpeKhm3Tb1Em3Su',
#               'width': 4192}],
#   'place_id': 'ChIJp25NJKKViDARrmgSjXmtAPs',
#   'plus_code': {'compound_code': 'MP9M+J8 Phoenix Bay, Port Blair, Andaman and '
#                                  'Nicobar Islands, India',
#                 'global_code': '7M3JMP9M+J8'},
#   'rating': 4.7,
#   'reference': 'ChIJp25NJKKViDARrmgSjXmtAPs',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 279,
#   'vicinity': 'behind old Anthropological Museum, MA Rd, Phoenix Bay, Port '
#               'Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6638864, 'lng': 92.75567649999999},
#                'viewport': {'northeast': {'lat': 11.66523402989272,
#                                           'lng': 92.75689587989272},
#                             'southwest': {'lat': 11.66253437010728,
#                                           'lng': 92.75419622010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Sinclairs Bayview Port Blair',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1080,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/102243026616141016928">Sinclairs '
#                                     'Bayview Port Blair</a>'],
#               'photo_reference': 'ATtYBwKTvm_J-OEBbZR-RRRFQh7pSD0QY_PvbiuOicX6F1Om5qgUTEWJkRcbM6T5BwT0yb9TS1MWjg_qppeBGf2v-e-3TWKHpl3Dl79L-os9lAzLEY4JOxhSSQwIoj8x0vq-SYVLdpQlBwdlMjNVU9SwfxwJLC5LEau4qCwXZ81ygH-PmQJw',
#               'width': 2048}],
#   'place_id': 'ChIJtVncXxaViDARhH1hzeEET-c',
#   'plus_code': {'compound_code': 'MQ74+H7 Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMQ74+H7'},
#   'rating': 4.2,
#   'reference': 'ChIJtVncXxaViDARhH1hzeEET-c',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 908,
#   'vicinity': 'Corbyns Cove Rd, South Point, Shadipur, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6699034, 'lng': 92.7287882},
#                'viewport': {'northeast': {'lat': 11.67119597989272,
#                                           'lng': 92.73013387989272},
#                             'southwest': {'lat': 11.66849632010728,
#                                           'lng': 92.72743422010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'UV Mansion',
#   'place_id': 'ChIJQyzaZTiViDAR6ilc-W7ebqo',
#   'plus_code': {'compound_code': 'MP9H+XG Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMP9H+XG'},
#   'rating': 5,
#   'reference': 'ChIJQyzaZTiViDAR6ilc-W7ebqo',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': 'Delanipur, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6641155, 'lng': 92.75465319999999},
#                'viewport': {'northeast': {'lat': 11.66553492989272,
#                                           'lng': 92.75596997989271},
#                             'southwest': {'lat': 11.66283527010728,
#                                           'lng': 92.75327032010726}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Vedic Homes Port Blair',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/114413622736683268154">arijit7969</a>'],
#               'photo_reference': 'ATtYBwISKHLvI-qkqNAUqmJUx27W4Ls0mCkJrB_ltOEErrE9e1I-Ku2PIwISIQFrV-70lKohtzo-k96kMnwBbrd_1U6gXvvAagOBHdlc8GD8Rkh70LQPC7PE8K8WXHPJYZi2eNIAPUtwtuFAo4KNiG4NPfyrwFf5R-xxzjbxUCanAugj8tbr',
#               'width': 4000}],
#   'place_id': 'ChIJZ2O5UeKViDARqq_SDBAEmSw',
#   'plus_code': {'compound_code': 'MQ73+JV Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMQ73+JV'},
#   'rating': 4.9,
#   'reference': 'ChIJZ2O5UeKViDARqq_SDBAEmSw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 8,
#   'vicinity': 'Ward no 11, D No 77 Mahabir Singh Rd, near Hotel Sinclair Bay '
#               'View, South Point, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6401133, 'lng': 92.7358694},
#                'viewport': {'northeast': {'lat': 11.64154552989272,
#                                           'lng': 92.73680832989272},
#                             'southwest': {'lat': 11.63884587010728,
#                                           'lng': 92.73410867010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Holiday Home',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 768,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/115764243727520085514">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwLuY7fVYuR-x8P8QVSNo-8TyA1iyg488F4qyL90KhWkpgyMGfFQD4DxwJ-7RXJAAtoolBu7l2AvYVtRIefNvcOJuUFW6-bssqg95uMEj9DXyVGF2b0FD2ICi7njvdWAd0l7VTeGz5_iLr12d1T1mmExK65XbJwmCVrtcfoT0kO2U4F_',
#               'width': 1024}],
#   'place_id': 'ChIJoV3m3weViDARdZIBZJqby9c',
#   'plus_code': {'compound_code': 'JPRP+28 Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JJPRP+28'},
#   'rating': 4.9,
#   'reference': 'ChIJoV3m3weViDARdZIBZJqby9c',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 24,
#   'vicinity': 'Beside GREF Headquarter, near Sai Baba Temple, Chakkargaon, '
#               'Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6804999, 'lng': 92.7217237},
#                'viewport': {'northeast': {'lat': 11.68186847989272,
#                                           'lng': 92.72307597989273},
#                             'southwest': {'lat': 11.67916882010728,
#                                           'lng': 92.72037632010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel Dream Palace',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/102678547955555372585">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwIpj4__m_u5xwP5BlVllG5-UI9fQ2QJGyCHThyyrMsRiA0Lj1n-bY_wX3UpWG0eCf0VhFHiMoENDBG9-tZt0QWqqCsslz5nPtGG2rOsfyIZBCZ0Vyt91TdTDKw9exGhIsNyHe8ij5IjuKHrl9EXhJyqyai_aJfXgaYAh53YOt7_A99d',
#               'width': 4032}],
#   'place_id': 'ChIJL63UxLCViDARBUHuBCJztMY',
#   'plus_code': {'compound_code': 'MPJC+5M Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPJC+5M'},
#   'rating': 5,
#   'reference': 'ChIJL63UxLCViDARBUHuBCJztMY',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2,
#   'vicinity': '30, Jawaharlal Nehru Rd, Haddo, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.675764, 'lng': 92.73972660000001},
#                'viewport': {'northeast': {'lat': 11.67705402989272,
#                                           'lng': 92.74104667989272},
#                             'southwest': {'lat': 11.67435437010728,
#                                           'lng': 92.73834702010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Sea Shell, Port Blair',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2760,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/112640210897222207243">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwK6-t8kuQG_36j5j1Y-ejJfvTDqdpfhaEw9PEPVRICz8dSSmrPTERv5eptxKVhm8I405HTPnrKG7NNW67LN3nljDXOL3GclHSgg5cMFDaqkTm050Ra9CzPCa1ytAqgexcOqtb6QTBNfdOZcboOfF82tPW8SxZY0H5QmPoW3tYT0j7CN',
#               'width': 4896}],
#   'place_id': 'ChIJRUy3L6KViDARK-IkN7dCJhc',
#   'plus_code': {'compound_code': 'MPGQ+8V Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPGQ+8V'},
#   'rating': 4.3,
#   'reference': 'ChIJRUy3L6KViDARK-IkN7dCJhc',
#   'scope': 'GOOGLE',
#   'types': ['night_club',
#             'lodging',
#             'bar',
#             'restaurant',
#             'food',
#             'point_of_interest',
#             'establishment'],
#   'user_ratings_total': 922,
#   'vicinity': 'Marine Hill, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6691281, 'lng': 92.74426869999999},
#                'viewport': {'northeast': {'lat': 11.67058267989272,
#                                           'lng': 92.74557327989271},
#                             'southwest': {'lat': 11.66788302010728,
#                                           'lng': 92.74287362010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Sun Ray Homes',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 644,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/111219776462797246817">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwJEH4EG_Xwpd9kz0xXtpw7eEqZvFCUd8duP7AZIlATkL7TJQBPh1zo5UuTrkD6DHSBd_pmuGyxeZ31w-zKZLJudlGC7DYwB-RfXArOv3Es3qQvxlHx1lFy1Aaxkf6dU_C75mIfjz6QsxWT6eOoYHGuCXiIS27bhZim3UR85UNDbKmOW',
#               'width': 1219}],
#   'place_id': 'ChIJMyscJnWViDARpJ6qfOh4HFw',
#   'plus_code': {'compound_code': 'MP9V+MP Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMP9V+MP'},
#   'rating': 4.8,
#   'reference': 'ChIJMyscJnWViDARpJ6qfOh4HFw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 87,
#   'vicinity': '4/8 Satyawati Niwas , Supply Line, Netaji Road, Rajiv Gandhi '
#               'Nagar, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6582097, 'lng': 92.7468737},
#                'viewport': {'northeast': {'lat': 11.65949507989272,
#                                           'lng': 92.74826057989272},
#                             'southwest': {'lat': 11.65679542010728,
#                                           'lng': 92.74556092010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Downing Street Inn',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3120,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/108063248068514874905">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwIvNgiGKXOjVi74JbIxpPi-F2E23Wa-fWjdm0pFatUnqP428oOJYdpGYNo-IOHC-avLszvjZXXXK61C9fLI8sH4Wfm9bcBkTG0bbiruSDjDmljBYVDDbkkUj1Aq3E1DSZWaGF2gL-FM__8ZAsMKgEI1fTunXZxdsTnhDu91yIEyg5F4',
#               'width': 4160}],
#   'place_id': 'ChIJyRXXbBiViDAR5cEQ0AND3bk',
#   'plus_code': {'compound_code': 'MP5W+7P Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMP5W+7P'},
#   'rating': 4.4,
#   'reference': 'ChIJyRXXbBiViDAR5cEQ0AND3bk',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 9,
#   'vicinity': 'Shadipur, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6239638, 'lng': 92.7205915},
#                'viewport': {'northeast': {'lat': 11.62523882989272,
#                                           'lng': 92.72196137989272},
#                             'southwest': {'lat': 11.62253917010728,
#                                           'lng': 92.71926172010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel MountView Pristine',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/106513318294105859619">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwKC-aCEBY_E9JJsiQiz3JQwVrhPgEk4yAglWCdLvozdd88tZVCAt24pTWjAVc8vKcs5lPL7YSPS6G5E4VwLFcMcp6Vp3LyOdB07APcb8tPvCIlRFjQmajahxN1VkPiu9Pj3Dat6IPeYEuh-_U0A3EyMZfI5giyoYo6I9uum1hmcPbVJ',
#               'width': 6000}],
#   'place_id': 'ChIJtxWHZl2ViDARdmnQmRjgcxU',
#   'plus_code': {'compound_code': 'JPFC+H6 Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JJPFC+H6'},
#   'rating': 5,
#   'reference': 'ChIJtxWHZl2ViDARdmnQmRjgcxU',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 28,
#   'vicinity': 'Pathergudda, Pahargaon, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.6710817, 'lng': 92.72378429999999},
#                'viewport': {'northeast': {'lat': 11.67242742989272,
#                                           'lng': 92.72513312989273},
#                             'southwest': {'lat': 11.66972777010728,
#                                           'lng': 92.72243347010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'PG homes',
#   'photos': [{'height': 853,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/104605064048623303664">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwLWO_CqGC-tIrHjXnvysmRg1heRQKX8TeoxgIsUYEtT6F3JGERWQlRZA7YHAzy-LeIQb5M4JLojXEVkpsd116c3n2jzD38kbHEXHo_AkRlb6taWlXcNCopZO_3kYBc27UVV3vJbWMgnBQnc4IeDoMrdIOXonDRb0yOqIRVH76E2osoW',
#               'width': 1280}],
#   'place_id': 'ChIJHVIewrWViDARy2gO0WPX3Lc',
#   'plus_code': {'compound_code': 'MPCF+CG Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JMPCF+CG'},
#   'rating': 5,
#   'reference': 'ChIJHVIewrWViDARy2gO0WPX3Lc',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2,
#   'vicinity': 'near Marriaman temple, Buniyadabad, Haddo, Port Blair'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 11.634044, 'lng': 92.71781349999999},
#                'viewport': {'northeast': {'lat': 11.63540942989272,
#                                           'lng': 92.71913057989272},
#                             'southwest': {'lat': 11.63270977010728,
#                                           'lng': 92.71643092010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Malakar Home Stay',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3840,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/113157732534729476066">A '
#                                     'Google User</a>'],
#               'photo_reference': 'ATtYBwIh8HrF7QrWp9KQm9PjYjzphIWDl5OdQ7YWOR-B2vnG7wEsD3gWfWPsTMUenCGZ9YSJz00XAG4YWCnqp6Y-No1tgXtj9gstDXuoCYQ5vEjfHS0ARFVyU2ZCEO_uVcxzwm433MInBsvKPaZLKkJw3ETVepBIH2y2nWHtmveWAxvvWaZO',
#               'width': 5760}],
#   'place_id': 'ChIJGSmDsumViDARrZd1hsigi5k',
#   'plus_code': {'compound_code': 'JPM9+J4 Port Blair, Andaman and Nicobar '
#                                  'Islands, India',
#                 'global_code': '7M3JJPM9+J4'},
#   'rating': 4.9,
#   'reference': 'ChIJGSmDsumViDARrZd1hsigi5k',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 12,
#   'vicinity': 'Royal Colony, Dollygunj, Port Blair'}]
#              City Name  Temperature  Maximum Temp  Wind  Cloudiness  Latitude  \
# 4               Maceió        27.00         27.00  3.60           0   -9.6658
# 42          Kaitangata        10.53         10.53  2.51           1  -46.2817
# 109  São João da Barra        27.00         27.00  5.14           0  -21.6403
# 159        Bandarbeyla        24.97         24.97  3.57           0    9.4942
# 237            Fortuna        11.91         13.33  5.66           1   40.5982
#
#      Longitude  Humidity                   Hotel Name
# 4     -35.7353        78           Pousada das Araras
# 42    169.8464        77        Kaitangata Motor Camp
# 109   -41.0511        78       POUSADA SOBRE AS ÁGUAS
# 159    50.8122        74                  JABIR HOTEL
# 237  -124.1573        71  THE REDWOOD RIVERWALK HOTEL

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City Name}</dd>
</dl>
"""
#<dt>Country</dt><dd>{Country}</dd>
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
#I created the second heat map
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=hotel_df['Humidity'], 
                                 dissipating=False, max_intensity=100,
# I added the marker layer ontop of the heat map                                 point_radius = 1)
marker_layer = gmaps.marker_layer(locations)

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
