# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key
print(weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# 1d54528d4bb3beecd81802b7ec3f3d12

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#lists for data
temp = []
lat = []
lng = []
hum = []
cld = []
mxTmp = []
citNm = []
wnd = []
# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        print(response['name']+ "  response number: " + str(len(citNm)))    
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        hum.append(response['main']['humidity'])
        cld.append(response['clouds']['all'])
        mxTmp.append(response['main']['temp_max'])
        citNm.append(response['name'])
        wnd.append(response['wind']['speed'])
    except:
        print("Not Found. Skipping")
        pass
    #add Rest
    
    time.sleep(0.2)
# Out:
# Te Anau  response number: 0
# Novikovo  response number: 1
# Rozivka  response number: 2
# Kapaa  response number: 3
# Maceió  response number: 4
# Kruisfontein  response number: 5
# Calabozo  response number: 6
# Tuktoyaktuk  response number: 7
# Bredasdorp  response number: 8
# Hilo  response number: 9
# Rikitea  response number: 10
# Severo-Kuril'sk  response number: 11
# East London  response number: 12
# Ushuaia  response number: 13
# Carnarvon  response number: 14
# Ahero  response number: 15
# Punta Arenas  response number: 16
# Puerto Escondido  response number: 17
# Dudinka  response number: 18
# Hermanus  response number: 19
# Tabas  response number: 20
# Porto Recanati  response number: 21
# Port Elizabeth  response number: 22
# Not Found. Skipping
# Mariehamn  response number: 23
# Not Found. Skipping
# Srandakan  response number: 24
# Inta  response number: 25
# Port Lincoln  response number: 26
# Arraial do Cabo  response number: 27
# Trairi  response number: 28
# Saint-Philippe  response number: 29
# Maibong  response number: 30
# Chokurdakh  response number: 31
# Hong Kong  response number: 32
# Faya  response number: 33
# Dikson  response number: 34
# Mossamedes  response number: 35
# Sovetskiy  response number: 36
# Pedasí  response number: 37
# Kharp  response number: 38
# Saint-Joseph  response number: 39
# Atuona  response number: 40
# Vila Franca do Campo  response number: 41
# Kaitangata  response number: 42
# Busselton  response number: 43
# George Town  response number: 44
# Constitución  response number: 45
# Cherskiy  response number: 46
# Harper  response number: 47
# Andrews  response number: 48
# Port Alfred  response number: 49
# Klaksvík  response number: 50
# Upernavik  response number: 51
# Yellowknife  response number: 52
# Nikolskoye  response number: 53
# Sayyan  response number: 54
# Pinawa  response number: 55
# Honningsvåg  response number: 56
# Provideniya  response number: 57
# Kavieng  response number: 58
# Jamestown  response number: 59
# Not Found. Skipping
# Los Llanos de Aridane  response number: 60
# Araouane  response number: 61
# Vestmannaeyjar  response number: 62
# Uruçuí  response number: 63
# Tuatapere  response number: 64
# Tegul'det  response number: 65
# Grobiņa  response number: 66
# Not Found. Skipping
# Makar'yev  response number: 67
# Zhigansk  response number: 68
# Bozhou  response number: 69
# Ribeira Grande  response number: 70
# Tasiilaq  response number: 71
# Qaanaaq  response number: 72
# Payo  response number: 73
# Meadow Lake  response number: 74
# Mar del Plata  response number: 75
# Igarka  response number: 76
# Not Found. Skipping
# Guerrero Negro  response number: 77
# Laguna  response number: 78
# Nederland  response number: 79
# Bingöl  response number: 80
# Touros  response number: 81
# Castro  response number: 82
# Bilibino  response number: 83
# Verkhnevilyuysk  response number: 84
# Lodja  response number: 85
# Albany  response number: 86
# Not Found. Skipping
# Cabo San Lucas  response number: 87
# Thompson  response number: 88
# Iqaluit  response number: 89
# Vaini  response number: 90
# Aklavik  response number: 91
# Beringovskiy  response number: 92
# Gobabis  response number: 93
# Ancud  response number: 94
# El Carmen  response number: 95
# Mukhen  response number: 96
# Belize  response number: 97
# San Quintín  response number: 98
# Fort Nelson  response number: 99
# Khatanga  response number: 100
# Aleksandrov Gay  response number: 101
# Not Found. Skipping
# Katsuura  response number: 102
# Adrar  response number: 103
# Mataura  response number: 104
# New Norfolk  response number: 105
# Doha  response number: 106
# Sarakhs  response number: 107
# Elko  response number: 108
# São João da Barra  response number: 109
# Puerto Ayora  response number: 110
# Narsaq  response number: 111
# Bluff  response number: 112
# Not Found. Skipping
# Butaritari  response number: 113
# Bagotville  response number: 114
# Kuytun  response number: 115
# Avarua  response number: 116
# Kenai  response number: 117
# Vågåmo  response number: 118
# Northam  response number: 119
# Malanville  response number: 120
# Not Found. Skipping
# Bethel  response number: 121
# Keminmaa  response number: 122
# Petropavlovsk-Kamchatskiy  response number: 123
# Artesia  response number: 124
# Omboué  response number: 125
# Barrow  response number: 126
# Jianning  response number: 127
# Coyhaique  response number: 128
# Palauig  response number: 129
# Hasaki  response number: 130
# Zalesovo  response number: 131
# Longyearbyen  response number: 132
# Altamira  response number: 133
# Bengkulu  response number: 134
# Bull Savanna  response number: 135
# Ereymentau  response number: 136
# Atambua  response number: 137
# Timizart  response number: 138
# Cape Town  response number: 139
# Aegviidu  response number: 140
# Coquimbo  response number: 141
# Not Found. Skipping
# Port Moresby  response number: 142
# Alofi  response number: 143
# Bathsheba  response number: 144
# Not Found. Skipping
# Not Found. Skipping
# Not Found. Skipping
# Dalnerechensk  response number: 145
# Lewistown  response number: 146
# Lana  response number: 147
# Ruwi  response number: 148
# Walla Walla  response number: 149
# Not Found. Skipping
# Polička  response number: 150
# Xinxiang  response number: 151
# Not Found. Skipping
# Airai  response number: 152
# Not Found. Skipping
# Codrington  response number: 153
# Bani Walid  response number: 154
# Linhares  response number: 155
# Monrovia  response number: 156
# Abancay  response number: 157
# Tura  response number: 158
# Not Found. Skipping
# Bandarbeyla  response number: 159
# Nome  response number: 160
# Dicabisagan  response number: 161
# Esperance  response number: 162
# Severomuysk  response number: 163
# Luzhou  response number: 164
# Grindavik  response number: 165
# Lorengau  response number: 166
# Souillac  response number: 167
# Ahipara  response number: 168
# Kahului  response number: 169
# Fuerte Olimpo  response number: 170
# Pevek  response number: 171
# Lebu  response number: 172
# Seymchan  response number: 173
# Samarai  response number: 174
# Not Found. Skipping
# Kayes  response number: 175
# Hobart  response number: 176
# Ponta do Sol  response number: 177
# Korsakov  response number: 178
# Moose Factory  response number: 179
# Jiuquan  response number: 180
# Lubao  response number: 181
# Not Found. Skipping
# Bereda  response number: 182
# Ostróda  response number: 183
# Not Found. Skipping
# Turukhansk  response number: 184
# Presidencia Roque Sáenz Peña  response number: 185
# Puerto Barrios  response number: 186
# Conceição do Araguaia  response number: 187
# Wattegama  response number: 188
# Tiksi  response number: 189
# Majene  response number: 190
# Not Found. Skipping
# Qaqortoq  response number: 191
# Jieshi  response number: 192
# Haimen  response number: 193
# Ketchikan  response number: 194
# Mandera  response number: 195
# Namatanai  response number: 196
# Sanjwal  response number: 197
# Aranda de Duero  response number: 198
# Warnes  response number: 199
# Talakan  response number: 200
# Kumul  response number: 201
# Srednekolymsk  response number: 202
# Not Found. Skipping
# Dongsheng  response number: 203
# Mayo  response number: 204
# Madimba  response number: 205
# Carballo  response number: 206
# Geraldton  response number: 207
# Dingle  response number: 208
# Keshod  response number: 209
# Boden  response number: 210
# Ordynskoye  response number: 211
# Cavalcante  response number: 212
# Not Found. Skipping
# Niquelândia  response number: 213
# Not Found. Skipping
# Torbay  response number: 214
# Lavrentiya  response number: 215
# Lata  response number: 216
# Faanui  response number: 217
# Not Found. Skipping
# Kavaratti  response number: 218
# Canutama  response number: 219
# Svetlaya  response number: 220
# Valley City  response number: 221
# Aykhal  response number: 222
# Mandalgovi  response number: 223
# Killybegs  response number: 224
# Wajima  response number: 225
# Guasdualito  response number: 226
# Saldanha  response number: 227
# Hibbing  response number: 228
# Buala  response number: 229
# Kajaani  response number: 230
# Chui  response number: 231
# Dobre Miasto  response number: 232
# Praia da Vitória  response number: 233
# Norman Wells  response number: 234
# Ābdānān  response number: 235
# Villa Carlos Paz  response number: 236
# Fortuna  response number: 237
# Juba  response number: 238
# Pangnirtung  response number: 239
# Boguchany  response number: 240
# Jāwā  response number: 241
# Road Town  response number: 242
# San Jose  response number: 243
# Haines Junction  response number: 244
# Hithadhoo  response number: 245
# La Asuncion  response number: 246
# Nanortalik  response number: 247
# Wajir  response number: 248
# Casper  response number: 249
# Agadez  response number: 250
# Qasigiannguit  response number: 251
# Salalah  response number: 252
# Arrondissement de Saint-Denis  response number: 253
# Honiara  response number: 254
# Fare  response number: 255
# Taoudenni  response number: 256
# Gallup  response number: 257
# Hay River  response number: 258
# Chernivtsi  response number: 259
# Valdivia  response number: 260
# Santa Rita  response number: 261
# Sinjai  response number: 262
# Bhādra  response number: 263
# Aksu  response number: 264
# Not Found. Skipping
# Ilulissat  response number: 265
# Dali  response number: 266
# Bobrovskiy  response number: 267
# Buritis  response number: 268
# Salinas  response number: 269
# Natal  response number: 270
# Yerbogachën  response number: 271
# Oranjemund  response number: 272
# Mafinga  response number: 273
# Garoowe  response number: 274
# Nishihara  response number: 275
# Not Found. Skipping
# Tual  response number: 276
# Qandala  response number: 277
# Necochea  response number: 278
# Tocopilla  response number: 279
# Haapiti  response number: 280
# Severn  response number: 281
# El Salvador  response number: 282
# Hoa Binh  response number: 283
# Witbank  response number: 284
# County Wicklow  response number: 285
# Batagay-Alyta  response number: 286
# Flinders  response number: 287
# Manitouwadge  response number: 288
# Puerto Palomas  response number: 289
# Muriwai Beach  response number: 290
# Viedma  response number: 291
# Hargeisa  response number: 292
# Bambous Virieux  response number: 293
# Opuwo  response number: 294
# Itarema  response number: 295
# Lukovetskiy  response number: 296
# Rundu  response number: 297
# Not Found. Skipping
# Beyneu  response number: 298
# Verkhnyaya Inta  response number: 299
# Teguise  response number: 300
# Saint Paul Harbor  response number: 301
# Shevchenkove  response number: 302
# Raudeberg  response number: 303
# Luanda  response number: 304
# Mineros  response number: 305
# Voyvozh  response number: 306
# Dunedin  response number: 307
# Clyde River  response number: 308
# Forestville  response number: 309
# Basco  response number: 310
# Karratha  response number: 311
# Kiryat Gat  response number: 312
# Shiraz  response number: 313
# Not Found. Skipping
# Leningradskiy  response number: 314
# Teya  response number: 315
# Masallātah  response number: 316
# Salym  response number: 317
# Yangi Marg`ilon  response number: 318
# Moctezuma  response number: 319
# Buenos Aires  response number: 320
# Not Found. Skipping
# Bǝrdǝ  response number: 321
# Lagoa  response number: 322
# Andros  response number: 323
# Kungurtug  response number: 324
# Islāmpur  response number: 325
# Walvis Bay  response number: 326
# Alausí  response number: 327
# Shingū  response number: 328
# Itaituba  response number: 329
# Sumkino  response number: 330
# Kalamare  response number: 331
# Bichura  response number: 332
# College  response number: 333
# Baykit  response number: 334
# São Filipe  response number: 335
# Tigil'  response number: 336
# Naze  response number: 337
# Not Found. Skipping
# Not Found. Skipping
# Byron Bay  response number: 338
# Bonavista  response number: 339
# Bara  response number: 340
# Kamenka  response number: 341
# Hobyo  response number: 342
# Vao  response number: 343
# Yārāda  response number: 344
# Pisco  response number: 345
# Abu Samrah  response number: 346
# Not Found. Skipping
# Mount Isa  response number: 347
# Sioux Lookout  response number: 348
# Hambantota  response number: 349
# Nara  response number: 350
# Mumford  response number: 351
# Esim  response number: 352
# Aripuanã  response number: 353
# Havøysund  response number: 354
# Not Found. Skipping
# Lompoc  response number: 355
# Raton  response number: 356
# Rocha  response number: 357
# Mahébourg  response number: 358
# San Patricio  response number: 359
# San Cristobal  response number: 360
# Not Found. Skipping
# San Policarpo  response number: 361
# Berbera  response number: 362
# North Bend  response number: 363
# Chimbote  response number: 364
# Ende  response number: 365
# Hamilton  response number: 366
# Prescott  response number: 367
# Bonthe  response number: 368
# San Lazaro  response number: 369
# Saskylakh  response number: 370
# Eau Claire  response number: 371
# Not Found. Skipping
# Terra Santa  response number: 372
# Sabha  response number: 373
# Bosobolo  response number: 374
# Not Found. Skipping
# Malakal  response number: 375
# Rameshki  response number: 376
# Junction City  response number: 377
# Not Found. Skipping
# Venado Tuerto  response number: 378
# Vlasenica  response number: 379
# Ariquemes  response number: 380
# Alugan  response number: 381
# Pacific Grove  response number: 382
# Meulaboh  response number: 383
# Rybachiy  response number: 384
# Keflavik  response number: 385
# Sinnamary  response number: 386
# Otradnoye  response number: 387
# Misratah  response number: 388
# Not Found. Skipping
# Ostrovnoy  response number: 389
# Not Found. Skipping
# Muroto-misakicho  response number: 390
# Tautira  response number: 391
# Mareeba  response number: 392
# Vardø  response number: 393
# Mabai  response number: 394
# Niğde  response number: 395
# Tateyama  response number: 396
# Sokolo  response number: 397
# Poronaysk  response number: 398
# Ust'-Omchug  response number: 399
# Xingyi  response number: 400
# Tokur  response number: 401
# Lake Cowichan  response number: 402
# Kostanay  response number: 403
# Oxapampa  response number: 404
# Talnakh  response number: 405
# Dargaville  response number: 406
# Port-Gentil  response number: 407
# Bayjī  response number: 408
# Kīhei  response number: 409
# Anadyr  response number: 410
# Gboko  response number: 411
# Ulverstone  response number: 412
# Polson  response number: 413
# Not Found. Skipping
# Chapais  response number: 414
# Hanoi  response number: 415
# Florø  response number: 416
# Masakin  response number: 417
# Mayumba  response number: 418
# Mackenzie  response number: 419
# Yenagoa  response number: 420
# Slobozia  response number: 421
# Isangel  response number: 422
# Zhengjiatun  response number: 423
# Not Found. Skipping
# Lake Charles  response number: 424
# Spirit River  response number: 425
# Not Found. Skipping
# Cidreira  response number: 426
# Aksarka  response number: 427
# Hailar  response number: 428
# Pontianak  response number: 429
# San Fernando del Valle de Catamarca  response number: 430
# Kudahuvadhoo  response number: 431
# Wewak  response number: 432
# Lokosovo  response number: 433
# Atbasar  response number: 434
# Brae  response number: 435
# Bud  response number: 436
# Not Found. Skipping
# Caravelas  response number: 437
# Wote  response number: 438
# Not Found. Skipping
# Nālūt  response number: 439
# Dezhou  response number: 440
# Baharly  response number: 441
# Konya Province  response number: 442
# Auki  response number: 443
# Novonikolsk  response number: 444
# Yeppoon  response number: 445
# Seoni  response number: 446
# Saint-Pierre  response number: 447
# Sumbe  response number: 448
# Nan  response number: 449
# Roald  response number: 450
# Inhambane  response number: 451
# Poum  response number: 452
# Bolzano  response number: 453
# Bridlington  response number: 454
# Westport  response number: 455
# Tamayo  response number: 456
# Mishelevka  response number: 457
# Rome  response number: 458
# Kloulklubed  response number: 459
# Suleja  response number: 460
# Nicoya  response number: 461
# Houndé  response number: 462
# Ambilobe  response number: 463
# Jahāngīrābād  response number: 464
# Laas  response number: 465
# Manali  response number: 466
# Manokwari  response number: 467
# Jaru  response number: 468
# Ust-Maya  response number: 469
# Alindao  response number: 470
# Sitka  response number: 471
# Cap Malheureux  response number: 472
# Bansang  response number: 473
# Florence  response number: 474
# Almaznyy  response number: 475
# Keti Bandar  response number: 476
# Vanavara  response number: 477
# Not Found. Skipping
# Dhidhdhoo  response number: 478
# Mountain Home  response number: 479
# Eskişehir  response number: 480
# Derzhavīnsk  response number: 481
# Kargopol'  response number: 482
# Pamanukan  response number: 483
# Balikpapan  response number: 484
# João Pinheiro  response number: 485
# Russell  response number: 486
# Tonantins  response number: 487
# Puerto Quijarro  response number: 488
# Not Found. Skipping
# Joshīmath  response number: 489
# Kyabram  response number: 490
# Asău  response number: 491
# Pitimbu  response number: 492
# Zyryanka  response number: 493
# Kathu  response number: 494
# Kikwit  response number: 495
# Quatre Cocos  response number: 496
# Kieta  response number: 497
# Abhā  response number: 498
# Dustlik  response number: 499
# Sorong  response number: 500
# Acurenam  response number: 501
# Okha  response number: 502
# Chengde  response number: 503
# Grand Gaube  response number: 504
# Mhlume  response number: 505
# Husavik  response number: 506
# Ialibu  response number: 507
# Campbell River  response number: 508
# Saint Stephen  response number: 509
# Alyangula  response number: 510
# Lugus  response number: 511
# Hualmay  response number: 512
# Betong  response number: 513
# Olafsvik  response number: 514
# Remedios  response number: 515
# Zhanakorgan  response number: 516
# Safi  response number: 517
# Ternate  response number: 518
# Cayenne  response number: 519
# Not Found. Skipping
# Not Found. Skipping
# Sajanan  response number: 520
# Soni  response number: 521
# Broome  response number: 522
# Saint George  response number: 523
# Ucluelet  response number: 524
# Vuktyl  response number: 525
# Phalodi  response number: 526
# Myanaung  response number: 527
# Carutapera  response number: 528
# Blairmore  response number: 529
# Koumac  response number: 530
# Suntar  response number: 531
# Porto Santo  response number: 532
# Cancún  response number: 533
# Port Blair  response number: 534
# Hue  response number: 535
# Huarmey  response number: 536
# Sampang  response number: 537
# Gushikawa  response number: 538
# Menomonie  response number: 539
# Blytheville  response number: 540
# Angoche  response number: 541
# Ovalle  response number: 542
# Aitape  response number: 543
# Ayan  response number: 544
# Benghazi  response number: 545
# Ha Tinh  response number: 546
# Kampot  response number: 547
# Partizanskoye  response number: 548
# Maragogi  response number: 549
# Røros  response number: 550
# Arrondissement de Saint-Quentin  response number: 551
# Talcahuano  response number: 552
# Not Found. Skipping
# Yulara  response number: 553
# Dryden  response number: 554
# Hare Bay  response number: 555
# Kawalu  response number: 556
# Portland  response number: 557
# Kassala  response number: 558
# Slave Lake  response number: 559
# Domoni  response number: 560
# Mustvee  response number: 561
# Askiz  response number: 562
# Diego de Almagro  response number: 563
# Carmo  response number: 564
# Cedar City  response number: 565
# Magadan  response number: 566

# %%
# I made a disc tionary of lists containing al the collected data. 
dl = {"City Name": citNm,\
      "Temperature": temp,\
      "Maximum Temp": mxTmp,\
      "Wind": wnd,\
      "Cloudiness": cld,\
      'Latitude': lat,\
      'Longitude':lng,\
      'Humidity': hum}
#I then made that dictionary of lists into a Data Frame
df = pd.DataFrame(dl)
df.head()

    #print(json.dumps(response, indent=4, sort_keys=True))
# Out:
#   City Name  Temperature  Maximum Temp  Wind  Cloudiness  Latitude  Longitude  \
# 0   Te Anau         9.56          9.56  0.19          39  -45.4167   167.7167
# 1  Novikovo       -10.45        -10.45  3.19           0   51.1537    37.8879
# 2   Rozivka        -5.45         -5.45  4.34           0   46.9385    35.7724
# 3     Kapaa        22.57         23.33  4.12          75   22.0752  -159.3190
# 4    Maceió        27.00         27.00  3.60           0   -9.6658   -35.7353
#
#    Humidity
# 0        83
# 1        71
# 2        40
# 3        88
# 4        78

# %%
df.to_csv('../output_data/cities.csv', index = False)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#No cities have a humidity above 100
df.sort_values(by=['Humidity'],  ascending=False)
# Out:
#           City Name  Temperature  Maximum Temp  Wind  Cloudiness  Latitude  \
# 510       Alyangula        23.00         23.00  3.68          63  -13.8483
# 312      Kiryat Gat        16.20         17.22  0.89         100   31.6100
# 459     Kloulklubed        24.00         24.00  5.88          75    7.0419
# 347       Mount Isa        23.00         23.00  0.21          99  -20.7333
# 183         Ostróda         2.44          5.56  6.17          90   53.6967
# ..              ...          ...           ...   ...         ...       ...
# 397          Sokolo        25.51         25.51  6.55          13   14.7328
# 74      Meadow Lake        17.95         19.44  5.66          20   34.8014
# 175           Kayes        29.70         29.70  5.40          90   14.0000
# 289  Puerto Palomas        21.00         21.00  2.06           1   31.7667
# 250          Agadez        27.66         27.66  3.46           5   19.7500
#
#      Longitude  Humidity
# 510   136.4192       100
# 312    34.7642       100
# 459   134.2556       100
# 347   139.5000       100
# 183    19.9649       100
# ..         ...       ...
# 397    -6.1219        10
# 74   -106.5436         9
# 175   -11.0000         8
# 289  -107.6167         8
# 250    10.2500         7
#
# [567 rows x 8 columns]

# %%
#This is a table of latitude vs Maximum Temp.
x_values = df['Latitude']
y_values = df['Maximum Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('City Latitude vs Max Temperature 3/09/2021')
plt.savefig('../output_data/City Latitude vs Max Temperature 3_09_2021.png')
plt.show()

# %%
#Impression: There seems to be a fairly dense arc of plots on this scatter plot that maps max temp in 
#relation to Latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = df['Latitude']
y_values = df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs Humidity 3/09/2021')
plt.savefig('../output_data/City Latitude vs Humidity 3_09_2021.png')
plt.show()

# %%
#Impression: There seems to be cliusters but not much of an onvious trend in this scatter plot of Humidity vs Latitude.

# %%
x_values = df['Latitude']
y_values = df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs Cloudiness 3/09/2021')
plt.grid(True)
plt.savefig('../output_data/City Latitude vs Cloudiness 3_09_2021.png')
plt.show()

# %%
#Impression: There is clustering along the y axis as certain percentages of couldiness are common regardless 
# of Latitude.

# %%
x_values = df['Latitude']
y_values = df['Wind']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind')
plt.title('City Latitude vs Wind 3/09/2021')
plt.grid(True)
plt.savefig('../output_data/City Latitude vs Wind 3_09_2021.png')
plt.show()

# %%
#Impression: There is an inverse bell curve concerning wind speed suggesting that the most severe wind is to be found
# at the most extreme Latitudes.

# %% [markdown]
# ## Linear Regression

# %%
# I need two new data frames. One for the northern hemisphere and one for the southern hemisphere. 
ndf = df.loc[df["Latitude"] > 0]
sdf = df.loc[df["Latitude"] < 0]

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = ndf['Latitude']
y_values = ndf['Maximum Temp']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Northern Hemisphere - City Latitude vs Max Temperature with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Northern Hemisphere - City Latitude vs Max Temperature with linear regression.png')
plt.show()
# Out:
# R-Value-0.8979894380630556

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = sdf['Latitude']
y_values = sdf['Maximum Temp']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Southern Hemisphere - City Latitude vs Max Temperature with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Southern Hemisphere - City Latitude vs Max Temperature with linear regression.png')
plt.show()
# Out:
# R-Value0.5697384526739677

# %%
#Impressions: Te northern hemisphere seems to have a much steeper slope of it's line and less spread from the line indicating
#higher corelation to latitude and temp when compared to the southern Hemisphere.

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = ndf['Latitude']
y_values = ndf['Humidity']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Northern Hemisphere - City Latitude vs Humidity with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Northern Hemisphere - City Latitude vs Humidity with linear regression.png')
plt.show()
# Out:
# R-Value0.22372716431480558

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = sdf['Latitude']
y_values = sdf['Humidity']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Southern Hemisphere - City Latitude vs Humidity with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Southern Hemisphere - City Latitude vs Humidity with linear regression.png')
plt.show()
# Out:
# R-Value0.16153259631770706

# %%
#Impression: Since the equater is represented by the right of the Northern Hemisphere scatter plot and the right 
# of the Southern Hemisphere scatterplot the lines are actually sloped in the opposite direction. There appears to be a
# low correlation though so the mildly apposing slopes seems to not be a very useful datum.

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = ndf['Latitude']
y_values = ndf['Cloudiness']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Northern Hemisphere - City Latitude vs Cloudiness with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Northern Hemisphere - City Latitude vs Cloudiness with linear regression.png')
plt.show()
# Out:
# R-Value0.10993449067371673

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = sdf['Latitude']
y_values = sdf['Cloudiness']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Southern Hemisphere - City Latitude vs Cloudiness with linear regression')
print(f'R-Value{res.rvalue}')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Southern Hemisphere - City Latitude vs Cloudiness with linear regression.png')
plt.show()
# Out:
# R-Value0.26457598607236543
# R-Value0.26457598607236543

# %%
#again the slopes seem to be opposite of eachother but due to a 
# very low correlation there is very little useful information in these scatter plots.

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = ndf['Latitude']
y_values = ndf['Wind']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Northern Hemisphere - City Latitude vs Wind Speed with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Northern Hemisphere - City Latitude vs Wind Speed with linear regression.png')
plt.show()
# Out:
# R-Value0.12172891722312289

# %%
#stat scatterplot and establish values to get linear regressin.
x_values = sdf['Latitude']
y_values = sdf['Wind']
#calculate needed values for linear regression
res = linregress(x_values, y_values)
#Square r
rsqd = res.rvalue**2
#Plot Line on scatter plot
plt.plot(x_values, res.intercept + res.slope*x_values, 'g')
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title('Southern Hemisphere - City Latitude vs Wind with linear regression')
print(f'R-Value{res.rvalue}')
plt.savefig('../output_data/Southern Hemisphere - City Latitude vs Wind Speed with linear regression.png')
plt.show()
# Out:
# R-Value-0.2440357848759407

# %%
#Impressions: Although there is more of a slope in the Southern Hemisphere 
#scatterplot there seems to be little correlation between the two datums overall.
